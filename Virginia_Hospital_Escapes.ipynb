# %% [markdown]
# # Virginia Hospital Escapes - A comparison of the venues surrounding Virginia hospitals
# ## IBM Capstone Project
# #### Author Micah C. Gray

# %% [markdown]
# ## Introduction

# %% [markdown]
# If you ever spent a night at a hospital, either as a patient or a staff member, you were probably grateful for any contact with the outside world. You might also have appreciated having venues nearby for food, prescriptions, flowers, or just a path with some fresh air. This report compares hospitals in the state of Virginia with respect to their surrounding venues, with the intent that your next hospital stay in Virginia is a little more freeing.
#
# This analysis draws upon location data obtained from Foursquare in order to explore the diversity of venues surrounding the 200-plus hospitals in Virginia. I discover the five most common venue types surrounding each hospital. I also list hospitals with little or few options for nearby food, pharmacies, or nature walks.

# %% [markdown]
# ## Data

# %% [markdown]
# Data about the hospitals in Virginia, including the geocoordinates, were obtained from http://www.lat-long.com/ while data about the venues surrounding the hospitals were obtained from Foursquare using a 1000 meter radius.

# %% [markdown]
# ### Data extraction and pre-conditioning

# %% [markdown]
# My first step was to obtain the hospital data. I copied the results of my Virginia hospital search from Lat-Long.com and pasted them into an Excel spreadsheet. I had to add the latitude and longitude values individually but it was a manageable task given the size of my data. Next I saved the spreadsheet and uploaded it to my jupyter notebook as a pandas dataframe, as shown below

# %%
# Uploading the .csv file from my local computer to IBM Watson project 

# Some code removed to conceal IBM credentials

df_hospitals = pd.read_excel(body)
df_hospitals.head()
# Out:
#                                      Name Feature Type  \
# 0           A B Adams Convalescent Center    Hospital
# 1            A D Williams Memorial Clinic    Hospital
# 2               Access Emergency Hospital    Hospital
# 3      Albemarle County Health Department    Hospital
# 4  Alexander W Terrell Memorial Infirmary    Hospital
#
#                     County State   Latitude  Longitude
# 0          Emporia (city)    VA   36.685705 -77.537758
# 1                Richmond    VA   37.539869 -77.430261
# 2                 Fairfax    VA   38.965666 -77.356930
# 3  Charlottesville (city)    VA   38.042083 -78.482789
# 4        Lynchburg (city)    VA   37.438475 -79.172247

# %%
# Next I save the dataframe as a .csv file for easy access
df_hospitals.to_csv('hospital_location_data.csv', index = None)

# %%
# import pandas as pd
df_hospitals2 = pd.read_csv('hospital_location_data.csv')
df_hospitals2.head()
# Out:
#                                      Name Feature Type  \
# 0           A B Adams Convalescent Center    Hospital
# 1            A D Williams Memorial Clinic    Hospital
# 2               Access Emergency Hospital    Hospital
# 3      Albemarle County Health Department    Hospital
# 4  Alexander W Terrell Memorial Infirmary    Hospital
#
#                     County State   Latitude  Longitude
# 0          Emporia (city)    VA   36.685705 -77.537758
# 1                Richmond    VA   37.539869 -77.430261
# 2                 Fairfax    VA   38.965666 -77.356930
# 3  Charlottesville (city)    VA   38.042083 -78.482789
# 4        Lynchburg (city)    VA   37.438475 -79.172247

# %% [markdown]
# ### Cleanup
# Now I begin cleaning up the hospital data.

# %%
# First I remove historical hospitals by dropping rows that have "historical" in the Name field.
bool_historical = df_hospitals2['Name'].str.contains('historical')
df_hospitals3=df_hospitals2[~bool_historical] # apply the boolean mask to the dataframe and save with a new name
df_hospitals3.head(14) # Let's see if it worked
# Out:
#                                       Name Feature Type  \
# 0            A B Adams Convalescent Center    Hospital
# 1             A D Williams Memorial Clinic    Hospital
# 2                Access Emergency Hospital    Hospital
# 3       Albemarle County Health Department    Hospital
# 4   Alexander W Terrell Memorial Infirmary    Hospital
# 5              Alleghany Memorial Hospital    Hospital
# 6              Alleghany Regional Hospital    Hospital
# 7                      Andrew Rader Clinic    Hospital
# 8                    Arlington Free Clinic    Hospital
# 9              Ashland Convalescent Center    Hospital
# 10                  Augusta Medical Center    Hospital
# 11          Bath County Community Hospital    Hospital
# 12                       Bayberry Hospital    Hospital
# 14                Blackstone Health Center    Hospital
#
#                      County State   Latitude  Longitude
# 0           Emporia (city)    VA   36.685705 -77.537758
# 1                 Richmond    VA   37.539869 -77.430261
# 2                  Fairfax    VA   38.965666 -77.356930
# 3   Charlottesville (city)    VA   38.042083 -78.482789
# 4         Lynchburg (city)    VA   37.438475 -79.172247
# 5         Covington (city)    VA   37.794847 -79.999502
# 6                Alleghany    VA   37.792204 -79.880990
# 7                Arlington    VA   38.870390 -77.076090
# 8                Arlington    VA   38.882449 -77.105439
# 9                  Hanover    VA   37.767643 -77.495540
# 10                 Augusta    VA   38.094575 -78.987023
# 11                    Bath    VA   37.996516 -79.830571
# 12          Hampton (city)    VA   37.022924 -76.338555
# 14                Nottoway    VA   37.080984 -77.994726

# %% [markdown]
# You can see that row 13 was dropped. Now I will reset the index.

# %%
df_hospitals3.reset_index(inplace=True, drop = True)
df_hospitals3.head(14)
# Out:
#                                       Name Feature Type  \
# 0            A B Adams Convalescent Center    Hospital
# 1             A D Williams Memorial Clinic    Hospital
# 2                Access Emergency Hospital    Hospital
# 3       Albemarle County Health Department    Hospital
# 4   Alexander W Terrell Memorial Infirmary    Hospital
# 5              Alleghany Memorial Hospital    Hospital
# 6              Alleghany Regional Hospital    Hospital
# 7                      Andrew Rader Clinic    Hospital
# 8                    Arlington Free Clinic    Hospital
# 9              Ashland Convalescent Center    Hospital
# 10                  Augusta Medical Center    Hospital
# 11          Bath County Community Hospital    Hospital
# 12                       Bayberry Hospital    Hospital
# 13                Blackstone Health Center    Hospital
#
#                      County State   Latitude  Longitude
# 0           Emporia (city)    VA   36.685705 -77.537758
# 1                 Richmond    VA   37.539869 -77.430261
# 2                  Fairfax    VA   38.965666 -77.356930
# 3   Charlottesville (city)    VA   38.042083 -78.482789
# 4         Lynchburg (city)    VA   37.438475 -79.172247
# 5         Covington (city)    VA   37.794847 -79.999502
# 6                Alleghany    VA   37.792204 -79.880990
# 7                Arlington    VA   38.870390 -77.076090
# 8                Arlington    VA   38.882449 -77.105439
# 9                  Hanover    VA   37.767643 -77.495540
# 10                 Augusta    VA   38.094575 -78.987023
# 11                    Bath    VA   37.996516 -79.830571
# 12          Hampton (city)    VA   37.022924 -76.338555
# 13                Nottoway    VA   37.080984 -77.994726

# %% [markdown]
# Just in case there are missing values, I'll drop any rows that have missing Latitutde coordinates.

# %%
print('shape prior to dropping missing values:', df_hospitals3.shape) # print the dimensions of the dataframe
df_hospitals3.dropna(subset=["Latitude"], axis=0, inplace=True)
print('shape after dropping missing values:', df_hospitals3.shape) # print the dimensions again to see changes
# Out:
# shape prior to dropping missing values: (247, 6)
# shape after dropping missing values: (247, 6)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Now get the Foursquare data

# %%
# Initialize Foursquare credentials
# Code removed to conceal credentials

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
# Define some parameters for the call to Foursquare
VERSION = '20180605' # Foursquare API version
radius = 1000 # Include venues within a 1 kilometer radius
INTENT = 'browse'
#search_query = 'Pharmacy' ## Optionally, search for food, garden, parks, walking trails

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# Define a function that returns a dataframe with nearby venue data given a names and pair of coordinates
def getNearbyVenues(name, lat, lng, radius=500):
    url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&intent={}'.format(
            CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, INTENT)
    # send the get request
    results = requests.get(url).json()['response']['venues']
    nearby_venues = json_normalize(results) # flatten JSON and save as a dataframe
    
    #troubleshoot
    #print(nearby_venues.head()) # take a peek at the raw dataframe
    
    # filter columns
    filtered_columns = ['name', 'location.lat', 'location.lng', 'location.distance', 'categories']
    nearby_venues =nearby_venues.loc[:, filtered_columns]
    
    #troubleshoot
    #print(nearby_venues.head()) # take a peek at the raw dataframe
    
    # filter the category for each row
    nearby_venues['categories'] = nearby_venues.apply(get_category_type, axis=1)
    
    #troubleshoot
    #print('After filtering categories \n', nearby_venues.head()) # take a peek at the raw dataframe
    
    # clean columns. This part is not always necessary.
    nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
    #print('After cleaning columns \n', nearby_venues.head()) # take a peek at the raw dataframe
    
    len = nearby_venues.size  # if 150 rows
    #print('length of nearby_venues:', len)
    index = 0
    names_list = []
    while index < len:   # 0 < 150
        names_list.append(name)
        index = index + 1
    names_series = pd.Series(data = names_list)
    #print('names_list size:', names_series.size)
    nearby_venues['Hospital']= names_series  #set each row in this column of nearby_venues to 'name'
    
    #troubleshoot
    #print('After adding hospital name... \n', nearby_venues.head()) # take a peek at the raw dataframe
    
    # add hospital data
    return(nearby_venues)

# %%
# Here I call the function above to get a dataframe with venues for all hospitals in Virginia
dictionary1 = {'name': ['value'], 'lat': ['NaN'],
               'lng': ['NaN'], 'distance': ['NaN'], 'categories': ['value'], 'Hospital': ['value']}
all_venues = pd.DataFrame(dictionary1)
for i, hospital in enumerate(df_hospitals3['Name']):
    all_venues = all_venues.append(getNearbyVenues(hospital, df_hospitals3.iloc[i,4],
                                                   df_hospitals3.iloc[i,5], radius))
    # Append the nearby venue data for each hospital in the dataframe

print('all_venues size:', all_venues.size)
all_venues.head()
# Out:
# all_venues size: 44466
#                                            name      lat      lng distance  \
# 0                                         value      NaN      NaN      NaN
# 0                 Greensville County Courthouse  36.6866 -77.5423      417
# 1                 New Century Hospice - Emporia  36.6853 -77.5435      511
# 2     Peggy Malone - State Farm Insurance Agent  36.6938  -77.538      898
# 3  Nationwide Insurance: Radke & Associates LLC  36.6846 -77.5432      504
#
#          categories                       Hospital
# 0             value                          value
# 0        Courthouse  A B Adams Convalescent Center
# 1    Medical Center  A B Adams Convalescent Center
# 2            Office  A B Adams Convalescent Center
# 3  Insurance Office  A B Adams Convalescent Center

# %%
#Save the dataframe to a .csv
all_venues.to_csv('all_venues_rough.csv')

# %%
# Get the dataframe from the .csv
import pandas as pd
all_venues = pd.read_csv('all_venues_rough.csv')

# %%
# Reset the index
all_venues.reset_index()
all_venues.head()
# Out:
#    Unnamed: 0                                          name        lat  \
# 0           0                                         value        NaN
# 1           0                 Greensville County Courthouse  36.686604
# 2           1                 New Century Hospice - Emporia  36.685332
# 3           2     Peggy Malone - State Farm Insurance Agent  36.693774
# 4           3  Nationwide Insurance: Radke & Associates LLC  36.684614
#
#          lng  distance        categories                       Hospital
# 0        NaN       NaN             value                          value
# 1 -77.542302     417.0        Courthouse  A B Adams Convalescent Center
# 2 -77.543467     511.0    Medical Center  A B Adams Convalescent Center
# 3 -77.538012     898.0            Office  A B Adams Convalescent Center
# 4 -77.543248     504.0  Insurance Office  A B Adams Convalescent Center

# %%
# Remove the null row and old index
all_venues.drop('Unnamed: 0', axis = 1, inplace = True)
all_venues.drop(labels = 0,axis = 0, inplace = True)
all_venues.head()
# Out:
#                                            name        lat        lng  \
# 1                 Greensville County Courthouse  36.686604 -77.542302
# 2                 New Century Hospice - Emporia  36.685332 -77.543467
# 3     Peggy Malone - State Farm Insurance Agent  36.693774 -77.538012
# 4  Nationwide Insurance: Radke & Associates LLC  36.684614 -77.543248
# 5                        Calvary Baptist Church  36.693578 -77.542884
#
#    distance        categories                       Hospital
# 1     417.0        Courthouse  A B Adams Convalescent Center
# 2     511.0    Medical Center  A B Adams Convalescent Center
# 3     898.0            Office  A B Adams Convalescent Center
# 4     504.0  Insurance Office  A B Adams Convalescent Center
# 5     988.0            Church  A B Adams Convalescent Center

# %%
# Rename the columns
all_venues.rename(columns={"name":"Venue","distance":"Meters from Hospital", "lat":"Venue Lat", "lng":"Venue Lng", "categories":"Category"}, inplace=True)

# %%
all_venues.head(35)
# Out:
#                                                 Venue  Venue Lat  Venue Lng  \
# 1                       Greensville County Courthouse  36.686604 -77.542302
# 2                       New Century Hospice - Emporia  36.685332 -77.543467
# 3           Peggy Malone - State Farm Insurance Agent  36.693774 -77.538012
# 4        Nationwide Insurance: Radke & Associates LLC  36.684614 -77.543248
# 5                              Calvary Baptist Church  36.693578 -77.542884
# 6                             Veteran's Memorial Park  36.688216 -77.540897
# 7                        LifeSafer Ignition Interlock  36.692696 -77.539833
# 8                          U-Haul Neighborhood Dealer  36.692470 -77.539980
# 9                                 dr. adams foot care  36.694221 -77.543526
# 10                                        L.U. Online  36.696852 -77.541702
# 11                               Care Advantage, Inc.  36.696022 -77.537526
# 12                             Samaritan Thrift Store  36.693121 -77.534464
# 13                                           Bus Stop  36.682384 -77.551267
# 14                                             Wkn It  36.697002 -77.541643
# 15                          First Presbyterian Church  36.687970 -77.542599
# 16                     Greensville County High School  36.682069 -77.543601
# 17                                            Telpage  36.678764 -77.547850
# 18                                    Habitat ReStore  36.693430 -77.535350
# 19                                 On The Roof @ Home  36.683383 -77.551303
# 20                  Liberty University Online Classes  36.683489 -77.551294
# 21                               Three Bears And Tree  36.682667 -77.552963
# 22                                      Logan's Diner  36.685598 -77.543243
# 23                               Royal Baptist Church  36.698586 -77.537117
# %%
# Let's see how many venues were returned for each hospital

all_venues.groupby('Hospital').count() # Just 30 venues per hospital
# Out:
#                                                     Venue  Venue Lat  \
# Hospital
# A B Adams Convalescent Center                          30         30
# A D Williams Memorial Clinic                           30         30
# Access Emergency Hospital                              30         30
# Albemarle County Health Department                     30         30
# Alexander W Terrell Memorial Infirmary                 30         30
# Alleghany Memorial Hospital                            30         30
# Alleghany Regional Hospital                            30         30
# Andrew Rader Clinic                                    30         30
# Arlington Free Clinic                                  30         30
# Ashland Convalescent Center                            30         30
# Augusta Medical Center                                 30         30
# Bath County Community Hospital                         30         30
# Bayberry Hospital                                      30         30
# Blackstone Health Center                               30         30
# Blakely House                                          30         30
# Blue Ridge Sanatorium                                  30         30
# Blue Ridge Speech and Hearing Center                   30         30
# Bon Secours - DePaul Medical Center                    30         30
# Bon Secours Mary Immaculate Hospital                   30         30
# Bristol Memorial Hospital                              30         30
# Brookwood Nursing Home                                 30         30
# Buchanan General Hospital                              30         30
# Burke Medical Center                                   30         30
# Burrell Memorial Hospital                              30         30
# C and O Hospital                                       30         30
# Camelot Hall Nursing Home                              30         30
# Capitol Medical Center                                 30         30
# Carilion Bedford Memorial Hospital                     30         30
# Carilion Franklin Memorial Hospital                    30         30
# Carilion Giles Memorial Hospital                       30         30
# ...                                                   ...        ...
# University of Virginia Kluge Children's Rehabil...     30         30
# University of Virginia Medical Center                  30         30
# University of Virginia Northridge Medical Offic...     30         30
# Vinton Family Medical Center                           30         30
# Virginia Baptist Hospital                              30         30
# Virginia Hospital Center                               30         30
# Virginia Military Institute Hospital                   30         30
# Virginia Treatment Center                              30         30
# Vogan Dental Clinic                                    30         30
# Walter Reed Convalescent Center                        30         30
# Warren Memorial Hospital                               30         30
# Waynesboro Community Hospital                          30         30
# Wellmont Lonesome Pine Hospital                        30         30
# West Hospital                                          30         30
# Westbrook Psychiatric Hospital                         30         30
# Western State Hospital                                 30         30
# Westminster Hospital                                   30         30
# Whaley Medical Center                                  30         30
# Whittaker Memorial Hospital                            30         30
# Williamsburg Community Hospital                        30         30
# Winchester Medical Center                              30         30
# Winchester Rehabilitation Center                       30         30
# Winslow Hospital                                       30         30
# Wise County Memorial Hospital                          30         30
# Woodbine Nursing and Convalescent Home                 30         30
# Woodburn Center for Mental Health                      30         30
# Woodmont Nursing Home                                  30         30
# Woodrow Wilson Rehabilitation Center                   30         30
# Woodside Hospital                                      30         30
# Wythe County Community Hospital                        30         30
#
#                                                     Venue Lng  \
# Hospital
# A B Adams Convalescent Center                              30
# A D Williams Memorial Clinic                               30
# Access Emergency Hospital                                  30
# Albemarle County Health Department                         30
# Alexander W Terrell Memorial Infirmary                     30
# Alleghany Memorial Hospital                                30
# Alleghany Regional Hospital                                30
# Andrew Rader Clinic                                        30
# Arlington Free Clinic                                      30
# Ashland Convalescent Center                                30
# Augusta Medical Center                                     30
# Bath County Community Hospital                             30
# Bayberry Hospital                                          30
# Blackstone Health Center                                   30
# Blakely House                                              30
# Blue Ridge Sanatorium                                      30
